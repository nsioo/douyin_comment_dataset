# %%
import re
import os
import pandas as pd
import numpy as np
import jieba 
import jieba.analyse as anls
import jieba.posseg as pseg
import matplotlib.pyplot as plt

# %%
def process(df):
    ff = pd.DataFrame(columns=['word', 'number'])
    s = {}
    for w in df['word']:
        if not w in s:
            s[w] = 1
        else:
            s[w] += 1
    
    words = list(s.keys())
    numbers = list(s.values())

    ff['word'] = words
    ff['number'] = numbers
    ff.sort_values(by=['number'], ascending=False, inplace=True)
    ff.reset_index(inplace=True, drop=True)
    return ff

#############################################################################################
def process_v2_txt(path):
    cut_result = set()
    key_words = set()
    phrase = {}
    with open(path, 'r', encoding='utf-8') as f:
            for line in f.readlines():
                line = map(lambda x : ''.join(re.findall('[\u4e00-\u9fff]', x)), line.strip())
                line = ''.join(line)
                cut_line = jieba.cut(line, cut_all=False, HMM=True)
                # split words
                print(list(cut_line))
                for i in list(cut_line):
                    cut_result.add(i)

                # key words
                space_line = ' '.join(list(cut_line))
                kw = anls.extract_tags(sentence=space_line, topK=10, allowPOS=('ns', 'n'))
                for i in kw:
                    key_words.add(i)

                # phrase
                words = pseg.cut(line)
                for _, flag in words:
                    if flag not in phrase:
                        phrase[flag] = 0
                    phrase[flag] += 1


    print(key_words, len(key_words))
    print(phrase)
    return cut_result
        



path = '../data_s2/single_vedio/dance/dance_result.txt'
jieba.load_userdict('../pos_neg/emoji.txt')
cut_result = process_v2_txt(path)
# Out:
# set() 0
# {'n': 23610, 'v': 21752, 'ug': 1, 'nr': 1941, 'uj': 4318, 'x': 7029, 'z': 1706, 'a': 8367, 'ul': 1630, 'b': 479, 'r': 7124, 'o': 826, 'd': 5872, 'c': 1170, 'ns': 591, 'p': 1283, 's': 312, 'm': 2263, 'nrt': 350, 'l': 1251, 'f': 794, 'q': 582, 'y': 580, 'ng': 263, 'vn': 220, 'nz': 205, 'zg': 195, 'e': 271, 't': 530, 'i': 265}

# %%
#######################################################################################
index2 = list(uni_result_v2.index)[:100]
index3 = list(uni_result_v2.index)[:100]
number2 = list(uni_result_v2.number)[:100]
number3 = list(uni_result_V3.number)[:100]


def graph_line(index2, index3, number2, number3):
    plt.figure(figsize=(8, 8))
    plt.plot(index2, number2, '-', color='red', label='result2',)
    plt.plot(index3, number3, '-', color='blue', label='result3')
    
    plt.legend(loc='best')
    # plt.title('The differences of domain specific lexicon with different seed words')
    # plt.xlabel('value of domain specific lexicon')
    plt.show()

#########################################################################################

def graph_line

# %%
seed_word = pd.read_csv('../cn_seed_v2_15.csv', encoding='utf-8-sig')
seed = seed_word['word']
taget2 = uni_result_v2.loc[index2, 'word']
taget3 = uni_result_V3.loc[index3, 'word']


cmb2 = set(taget2) & set(seed)
cmb3 = set(taget3) & set(seed)

print('top100 from result2:', set(taget2))
print('top100 from result3:', set(taget3))
print(set(seed))
print(cmb2)
print(cmb3)

rate2 = len(cmb2) / len(seed)
rate3 = len(cmb3) / len(seed)

print('the rate of cmb with seed words')
print('--'*80)
print('the rate of result2 :{},  the rate of result3 : {}'.format(rate2, rate3))
# Out:
# top100 from result2: {'老板', '厉害', '觉得', '太', '不是', '小', '玩', '比心', '女人', '手机', '奸笑', '不会', '酷拽', '孩子', '看', '现在', '逼', '挺', '看到', '可能', '好像', '老', '加油', '知道', '以为', '找', '直接', '车', '没', '怕', '最后', '这种', '没有', '说', '真', '爱', '牛', '灵机一动', '年', '钱', '人', '这是', '喝', '有钱', '好看', '别人', '感谢', '不能', '想', '赞赞', '死', '不错', '做', '东西', '赞', '中国', '真的', '出来', '微笑', '是不是', '发呆', '需要', '哈哈哈哈', '喜欢', '再', '问题', '懂', '捂脸', '下', '以后', '大笑', '哈哈哈', '去', '拍', '应该', '一下', '玫瑰', '带', '泣不成声', '鼓掌', '笑', '流泪', '老师', '男人', '赞赞赞', '泪奔', '感觉', '已经', '笑哭', '呲牙', '看看', '不要', '视频', '走', '买', '抠鼻', '一天', '吃', '有点', '好'}
# top100 from result3: {'厉害', '觉得', '太', '不是', '小', '玩', '比心', '女人', '手机', '卧槽', '奸笑', '不会', '酷拽', '孩子', '看', '现在', '评论', '一起加油', '挺', '看到', '可能', '呆无辜', '小姐姐', '好像', '支持', '加油', '抖音', '知道', '以为', '找', '开', '直接', '车', '没', '最后', '这种', '没有', '说', '真', '爱', '灵机一动', '年', '钱', '人', '这是', '有钱', '好看', '别人', '感谢', '不能', '漂亮', '想', '赞赞', '死', '做', '东西', '赞', '美女', '中国', '真的', '微笑', '是不是', '发呆', '喜欢', '哈哈哈哈', '再', '刷', '懂', '捂脸', '以后', '哈哈哈', '去', '拍', '应该', '一下', '腿', '玫瑰', '一定', '带', '泣不成声', '鼓掌', '笑', '流泪', '老师', '男人', '赞赞赞', '泪奔', '感觉', '已经', '可爱', '呲牙', '看看', '不要', '视频', '走', '买', '抠鼻', '吃', '有点', '好'}
# {'玫瑰', '感谢', '鼓掌', '好听', '爱心', '哈哈', '漂亮', '分手', '赞赞', '加油', '难受', '差', '绝望', '垃圾', '傻子', '心碎', '可爱', '大哭', '错', '害怕', '微笑', '对不起', '举报', '喜欢', '小心', '可怕', '好看', '好', '怀疑'}
# {'玫瑰', '微笑', '感谢', '鼓掌', '喜欢', '好看', '赞赞', '加油', '好'}
# {'玫瑰', '微笑', '感谢', '鼓掌', '漂亮', '喜欢', '可爱', '好看', '赞赞', '加油', '好'}
# the rate of cmb with seed words
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# the rate of result2 :0.3,  the rate of result3 : 0.36666666666666664

# %%
## 高频词同时出现的概率
result2txt = pd.read_csv('../result_v2_process.txt', header=None, encoding='utf-8-sig')
result3txt = pd.read_csv('../result_v3_process.txt', header=None, encoding='utf-8-sig')



def process_v2(df):
    c1 = 0
    c2 = 0
    for line in df[0]:
        line = ''.join(line)
        line = set(line.split(' '))
        if set()
        
        print(line)


process_v2(result2txt)

# print(' '.join(result2txt.loc[0]).split(' '))
# Out:
# , '酸', '捂脸'}
# {'迦', '哈哈哈哈', '囧'}
# {'小子', '占', '便宜'}
# {'今天', '开心'}
# {'南城', '以北'}
# {'不亏', '永远', '随便'}
# {'到底', '儿', '爹'}
# {'玩', '老溜', '现在', '小时候'}
# {'叶', '半夏', '捂脸'}
# {'老祖', '开口', '安人'}
# {'捂脸'}
# {'同学', '橙', '酸', '捂脸'}
# {'迦', '哈哈哈哈', '囧'}
# {'小子', '占', '便宜'}
# {'今天', '开心'}
# {'东', '大四', '牌楼', '校区', '呲牙'}
# {'硕士', '没读', '感觉'}
# {'毕业', '难', '不好', '考', '硕士', '意思', '博士'}
# {'捂脸', '仰望', '博士'}
# {'不了', '考不上', '毕', '硕士', '呲牙', '业', '博士'}
# {'看', '难道', '不了', '考不上', '毕', '硕士', '业', '博士'}
# {'回复', '导师', '看', '联系'}
# {'东南大学', '这是', '喜欢', '学校'}
# {'难考', '现在', '学校', '好', '以前', '博士'}
# {'已经', '哥', '考博', '爆炸'}
# {'小精灵', '呆无辜', '熬夜'}
# {'走读', '寄宿', '不能', '必须'}
# {'小', '公主', '买菜'}
# {'生理', '差异', '苛求', '感觉', '辅助', '互相理解', '经历', '无可', '去', '岁', '想要', '买房', '逆转', '不要'}
# {'会生', '意大利', '孩子', '微笑', '吃', '女', '我要', '面'}
# {'段时间', '厚', '茧', '过年', '打麻将'}
# {'吃', '捂脸'}
# {'卧槽', '表达', '心情'}
# {'心痛', '我会', '花', '赚来', '姑娘', '钱', '别人'}
# {'长字辈', '字辈'}
# {'钱', '看', '说', '只能', '辛苦', '点花', '分上', '省', '省点'}
# {'好看', '这鞋'}
# {'大师', '劈', '砖'}
# {'老茧', '皮肤', '长茧', '修车', '细皮嫩肉', '同事', '一起', '一手', '手', '关系'}
# {'这手', '遭罪', '老', '冬天'}
# {'男人', '自豪', '事'}
# {'爸爸', '好', '年轻'}
# {'老茧', '没有', '知道', '弄掉', '保护层'}
# {'泣不成声', '楠鑫'}
# {'没', '见'}
# {'好', '题材'}
# {'几年', '拍', '看'}
# {'冬天', '可美', '没错', '没事', '东北', '这点', '看看'}
# {'音拍', '好家伙', '抖', '一年'}
# {'黑色', '小伙子', '跑', '看', '没到', '衣服', '好几年'}
# {'峰哥', '一起加油', '感染', '自信'}
# {'工作', '告诉'}
# {'赞', '自信', '哈哈哈', '胖子', '小'}
# {'指指点点', '天天', '捂脸'}
# {'以后', '好像', '发挥', '看到', '陈'}
# {'帅', '男人', '自信'}
# {'说实话', '衣品', '这块', '呲牙', '不错', '微胖'}
# {'无缘', '全靠', '嫂子'}
# {'做', '人'}
# {'老乡', '鼓掌', '江西'}
# {'大肚腩', '捂脸'}
# {'到底', '胖虎', '干嘛', '打脸'}
# {'沙拉', '吃少', '基本', '可能'}
# {'帅哥', '呲牙'}
# {'这是', '干嘛', '搞不懂'}
# {'笑面虎', '泣不成声', '真像', '微笑'}
# {'沙拉', '吃', '腹肌'}
# {'一块', '就够'}
# {'看', '捂脸', '家', '不想', '一眼', '顺眼', '别人'}
# {'没输', '呲牙', '气质', '一块'}
# {'坏笑', '长得', '岳云鹏', '有点像'}
# {'沙拉', '吃', '捂脸'}
# {'饿', '老板', '混', '带', '冒点', '萍乡', '赞', '一起', '兜'}
# {'气质', '捂脸', '矮', '人'}
# {'下次', '做', '慈善', '呲牙', '估计', '拍拍'}
# {'有会', '一块'}
# {'看', '捂脸', '家', '不想', '一眼', '顺眼', '别人'}
# {'没输', '呲牙', '气质', '一块'}
# {'坏笑', '长得', '岳云鹏', '有点像'}
# {'沙拉', '吃', '捂脸'}
# {'饿', '老板', '混', '带', '冒点', '萍乡', '赞', '一起', '兜'}
# {'气质', '捂脸', '矮', '人'}
# {'下次', '做', '慈善', '呲牙', '估计', '拍拍'}
# {'有会', '一块'}
# {'拉', '锯子', '好家伙'}
# {'捂脸', '问下', '后续', '想', '处理'}
# {'中提琴', '大哥'}
# {'知音', '太多'}
# {'捂脸', '大提琴', '生命危险', '拉', '没想到'}
# {'锯断', '终于'}
# {'泪奔', '没事', '修'}
# {'多多', '买'}
# {'感谢', '石化', '捂脸'}
# {'续弦', '捂脸'}
# {'奸笑', '淡定'}
# {'周九良', '大提琴', '改', '三弦', '不拉'}
# {'真', '木头', '精彩'}
# {'我要', '退票', '指定', '喊'}
# {'弦', '崩', '终有断', '一天', '太紧'}
# {'没', '不少', '钱'}
# {'捂脸', '搅', '场子', '哥们'}
# {'哥们', '姥姥', '先', '大笑', '大道理', '款换', '讲', '再'}
# {'项目', '工程', '来说', '小', '几千万'}
# {'两天', '小生意', '块钱', '下来', '先借', '工地', '工程款', '多万'}
# {'酷拽', '发呆', '捂脸', '已经', '泣不成声', '今年', '滑过去', '考核', '任务', '不是', '年', '工资', '业绩', '几千万', '真的'}
# {'做', '真正', '低调', '工程'}
# {'说', '好像'}
# {'大爷', '施工员', '看门', '大点', '万左右', '稍微', '工资', '工地'}
# {'说', '不少', '真的'}
# {'老哥', '跑', '混不下去', '直播', '挣钱', '吸粉', '工地'}
# {'上鑫', '仔好', '捂脸', '爱', '请'}
# {'光', '说实话', '捂脸'}
# {'退', '见面', '拨', '款', '保证金', '进度', '问'}
# {'谈不成', '项目', '经常', '捂脸', '二手房', '卖', '谈', '几千万'}
# {'朋友', '上班', '好生'}
# {'活', '项目', '总', '以为', '下来', '工资', '死'}
# {'四千', '杂工', '清洁工', '工程', '任何人', '低于', '不会'}
# {'特别', '这种', '一年', '挣', '多少钱', '说', '块钱', '捂脸', '信用卡', '吹', '没过多久', '人'}
# {'看', '超', '感觉', '作品', '工资', '几个'}
# {'家庭', '影响', '一生', '原生', '人'}
# {'好', '看', '温柔'}
# {'看', '问问', '纪录片', '泣不成声', '爱心'}
# {'得到', '没', '温暖', '儿子', '父爱'}
# {'跑', '厉害', '对手', '碰到', '以后', '好好', '教', '小猩猩'}
# {'经常', '出门', '看来', '小孩'}
# {'这种', '没有', '说', '世界', '男人', '好', '两个', '我敢'}
# {'山', '父爱'}
# {'詹姆斯', '赛季', '科比', '纪录片'}
# {'年轻', '微笑', '这时候', '詹', '老', '好'}
# {'自然', '小孩', '醒', '睡', '中国'}
# {'说', '第一句', '窝里', '看'}
# {'周二', '看', '今天', '老詹该', '起床'}
# {'布朗', '老家伙', '泣不成声', '曾经', '温柔', '尼'}
# {'人品', '没有', '地方', '詹姆斯', '科密们', '库里', '黑', '值得'}
# {'女人', '一堆', '捂脸', '算了吧', '罗'}
# {'赞赞'}
# {'人品', '没有', '地方', '詹姆斯', '科密们', '库里', '黑', '值得'}
# {'女人', '一堆', '捂脸', '算了吧', '罗'}
# {'赞赞'}
# {'刚看', '这才', '坎', '破产', '越往后', '个个', '要命', '月', '今年', '刚刚开始', '节目', '逐渐', '出现', '严重', '越', '几个', '恢复'}
# {'亚洲', '第一'}
# {'想', '去', '打工'}
# {'这种', '感觉', '惊喜', '环境', '温馨', '人', '上班'}
# {'呲牙', '好', '小姐姐'}
# {'电梯', '敞亮'}
# {'屋', '高岛'}
# {'银座', '没开', '捂脸'}
# {'东西', '不买', '去', '屋', '高岛'}
# {'不敢', '套餐', '十四天', '捂脸', '回来', '去', '核酸', '送'}
# {'难道', '保留', '全都', '不是', '屋', '区', '食品', '开业', '高岛'}
# {'好久不见', '家门'}
# {'赞', '干净', '礼貌', '文明'}
# {'真的', '文化', '做', '喷', '问题', '这类', '可能', '没什么', '白眼', '社会', '日本', '上进', '中国', '职业', '确实'}
# {'我信', '鬼'}
# {'就行', '六十'}
# {'老板', '大点加', '差不多', '碗', '说', '打眼', '背', '不是', '买', '锅', '左右', '御用', '雍正', '檄文', '宫廷'}
# {'清朝', '问题', '龙纹', '是不是', '人能', '干', '这行', '已经', '后面', '能见', '捂脸', '说明', '加个', '现在', '光', '麻烦', '一下'}
# {'乐', '时间', '捂脸', '咱大景德', '看看', '一下'}
# {'看', '心里', '害怕'}
# {'两块', '五十个', '起卖'}
# {'看', '砍价', '不是', '文物', '呲牙'}
# {'赞赞'}
# {'真假', '几个', '我家'}
# {'双簧', '表演'}
# {'东西', '收徒', '门', '不了', '入', '喜欢'}
# {'表演', '大头菜', '纯属'}
# {'北京', '写', '碗底', '欢迎'}
# {'老板', '钱', '看', '挣瓶', '汽水', '去', '两千八', '零'}
# {'狗盆', '以前', '说不定'}
# {'捂脸', '想', '面', '好', '拿来', '泡泡'}
# {'手艺', '现代', '贾', '残次品', '明明', '工业'}
# {'真敢', '买'}
# {'东西', '块钱', '专业', '赞', '喊'}
# {'捂脸', '大粪', '时期', '不是', '雍正', '拿来', '价'}
# {'专家'}
# {'大白菜', '捂脸'}
# {'老板', '笑', '一边', '知道', '名堂', '进货'}
# {'去', '两个'}
# {'好', '别当真', '看看', '大家'}
# {'未', '马', '走', '喊'}
# {'老板', '买', '高兴'}
# {'雍正', '发呆', '逗'}
# {'说', '够', '好'}
# {'爽', '掉', '不是'}
# {'应该', '砍价'}
# {'雍正', '专家'}
# {'正式工', '捂脸', '干', '单位', '好多', '影响', '开', '公司', '个体', '外面'}
# {'买卖', '梦想'}
# {'貌似', '有裂'}
# {'不是', '冰种'}
# {'看', '地方', '没什么', '开窗', '看出', '糯冰', '快到'}
# {'这是', '市场', '玉石'}
# {'没', '裂', '捂脸', '看见'}
# {'一万五', '泪奔', '人民币'}
# {'淘个', '帮忙', '牌子'}
# {'档主', '便宜', '夸', '面前', '好能'}
# {'山水', '半', '看', '石'}
# {'黄金', '至少', '卖个', '瞳', '万'}
# {'想', '光', '捡漏', '赚'}
# {'亿', '十个'}
# {'肯定', '做', '镯子', '中间', '牌子', '小花', '可能', '不行'}
# {'牌子', '万起', '一堆'}
# {'老子', '一跳', '微笑'}
# {'不敢', '演员', '演', '导演'}
# {'不吃', '里面', '吃', '肉', '舔屏'}
# {'不吃', '没', '泡面', '微笑', '吃', '月', '两个'}
# {'抖音', '看', '亿哥'}
# {'懂得', '已经', '释然', '疫情', '可能', '珍惜', '拥有'}
# {'快乐', '懂', '社科', '觉得', '遵从', '及时行乐', '心理', '涉及', '顺其自然', '决定', '反正', '总结', '一辈子', '人'}
# {'厉害', '剑桥', '放弃', '居然', '好', '博士'}
# {'容易', '捂脸', '明白', '人生', '隔离', '经历'}
# {'疑问', '最近', '泣不成声', '纠结', '读博', '刷', '工作'}
# {'本来', '不用', '哈哈哈', '搞笑', '一放', '变得', '皱眉'}
# {'说', '幻想', '捂脸', '成功'}
# {'快乐', '捂脸', '借口', '努力', '现在', '下去', '而活'}
# {'市值', '东西', '人为', '幸福感', '指标', '量化', '人生', '增长', '利润', '不能', '财富', '无法', '比较', '而活', '体验', '明明', '重视', '销售额', '得不到', '健康'}
# {'容易', '利弊', '产生矛盾', '事情', '陷入', '大多数', '变成', '东西', '价值', '来源于', '定义', '发现', '不顺心', '自我', '困难', '其实', '两难', '剩下', '选择', '非常', '主观', '了解'}
# {'直到', '带', '再也', '搞钱', '根本', '不是', '从小', '活在', '听不见', '知道', '声音', '等到', '问', '一句', '长大', '内心', '喜欢', '其实', '里', '想要', '巧妙', '人', '灵魂', '仍旧', '大学毕业', '别人'}
# {'快乐', '没有', '悲哀', '越老越', '后浪', '成功', '努力', '可言'}
# {'想', '问'}
# {'捂脸', '感觉', '解脱', '轻松', '放弃', '其实', '有种'}
# {'有点', '哈哈哈', '老师', '哈哈哈哈', '可爱'}
# {'捂脸', '小区', '脑血栓', '有个'}
# {'好', '搞笑'}
# {'不敢', '五个', '喇叭', '怕', '微笑', '牙', '送走', '保安', '出入', '八颗', '小区'}
# {'起码', '保安', '行', '捂脸'}
# {'哈哈哈', '真实', '太'}
# {'房子', '套', '便宜', '投资', '想着', '请', '到手', '买房', '不会'}
# {'韩', '红红火火', '恍恍惚惚', '老', '小', '韩家'}
# {'过于', '视频', '内容', '真实'}
# {'哈哈哈', '哈哈哈哈', '作曲家'}
# {'成功', '笑', '猪声', '捂脸'}
# {'五个', '保安', '三个', '牙'}
# {'保安', '三个', '颗牙'}
# {'真实', '捂脸'}
# {'没', '年轻', '夸张', '保安', '高', '小区'}
# {'大爷', '捂脸', '颗牙'}
# {'牙', '保安', '三颗', '大门', '小区', '四个', '我家'}
# {'捂脸', '小区', '老', '人'}
# {'收', '说', '看门', '这麻', '安排', '或许', '请', '其实', '门费来', '收看', '不要'}
# {'小伙', '人变', '尴尬', '容易', '老头', '不到', '就让', '保安', '老', '精神', '几年', '变成', '众所周知', '糟', '职业'}
# {'快点', '老', '捂脸'}
# {'真实', '太'}
# {'保安', '三年', '可能', '玩', '彩票', '几个'}
# {'真实', '妈', '太'}
# {'评论', '看', '笑', '死', '芋泥', '啵'}
# {'形象', '表达'}
# {'压力', '太大'}
# {'快点', '老', '捂脸'}
# {'真实', '太'}
# {'保安', '三年', '可能', '玩', '彩票', '几个'}
# {'真实', '妈', '太'}
# {'评论', '看', '笑', '死', '芋泥', '啵'}
# {'形象', '表达'}
# {'压力', '太大'}
# {'离职', '超级', '人', '羡慕'}
# {'同事'}
# {'眼白', '灵机一动', '好白'}
# {'徐总', '灵机一动'}
# {'先撇', '初中', '打仗', '手机'}
# {'同学', '直接', '铅笔'}
# {'拿牙套', '气', '同学', '泣不成声', '砸'}
# {'傻', '捂脸', '巴登', '两码', '买', '潮'}
# {'天空', '城', '精神'}
# {'合身', '微笑', '现在', '审美观', '女性', '衣服', '呲牙', '殊不知', '重要'}
# {'实话', '天天', '耶', '空格'}
# {'正好', '味', '草莓', '精神', '小', '番茄酱', '大就潮'}
# {'效果', '瓶子', '本来', '牛', '想', '踢', '逼'}
# {'赞', '橄榄球'}
# {'技术含量', '说实话', '没有', '一脚', '下去', '运气'}
# {'谱', '捂脸', '不靠', '事情', '见'}
# {'没', '这脚头', '反正'}
# {'爷玲爷', '玲爷玲'}
# {'表示', '充电器', '看不起'}
# {'几天', '放暑假', '看看', '返校'}
# {'忘记', '吃', '带'}
# {'开学', '北京高校'}
# {'卫生巾', '电脑书', '药'}
# {'物理学', '捂脸'}
# {'壳', '同款', '平板'}
# {'课本', '微笑', '二十多斤', '贴心', '不同', '学校', '各科', '邮来'}
# {'充电器', '不戴'}
# {'工作效率', '带', '感觉', '一点儿', '电脑', '儿', '笔记本', '太低', '好', '平板'}
# {'捂脸', '使', '不好', '口罩', '其实'}
# {'捂脸', '保护套', '不好', '真心', '巨沉'}
# {'这是', '捂脸', '隔离', '准备', '好'}
# {'十几公斤', '吃', '宿舍', '带', '微笑', '一箱', '新疆', '肉', '不能', '沈阳', '开学', '今天', '大学', '过年', '吃点素', '几天', '室友', '问'}
# {'路', '飞', '注意'}
# {'捂脸', '手机', '零食', '电脑', '加个'}
# {'微笑', '开学', '不让', '开', '北京', '河北'}
# {'宝带', '好', '抱拳', '充电'}
# {'捂脸', '带', '家里', '口罩', '卖', '一周', '学校', '过来', '发个'}
# {'装进', '车里', '微笑', '返校', '箱子', '年', '从不'}
# {'已经', '暑假', '寒假', '看'}
# {'箱子', '为啥', '看'}
# {'抠鼻', '笔记', '作业'}
# {'没', '多久', '捂脸', '放假'}
# {'一起加油', '来看我'}
# {'昨天', '特意', '开学', '强调', '老师', '一次', '灵机一动'}
# {'已经', '暑假', '寒假', '看'}
# {'箱子', '为啥', '看'}
# {'抠鼻', '笔记', '作业'}
# {'没', '多久', '捂脸', '放假'}
# {'一起加油', '来看我'}
# {'昨天', '特意', '开学', '强调', '老师', '一次', '灵机一动'}
# {'活到', '人能', '两百岁', '那种', '灵机一动'}
# {'一个月', '借钱', '朋友', '以后', '过日子', '可能', '人'}
# {'灌依云', '品牌', '自我', '喝', '瓶子', '满足', '农夫山泉', '里', '看看', '人', '出来'}
# {'头发', '剪'}
# {'拉', '蹭', '东西', '胯'}
# {'保险', '音响', '卖', '呲牙', '扛着'}
# {'卖', '保险'}
# {'逼', '赢', '牛'}
# {'标准', '太', '白眼', '英文'}
# {'考虑一下', '动力', '哥们', '白眼', '拜亚'}
# {'卖', '保险'}
# {'哈哈哈哈'}
# {'音响', '寻思', '我家', '刘庆轩'}
# {'哥', '链接', '项链', '求'}
# {'疑问', '装', '大哥', '实力', '不行'}
# {'卖', '保险'}
# {'线', '不够'}
# {'卖', '保险'}
# {'实话', '多久', '保险', '讲', '卖', '买', '音响'}
# {'卖', '保险'}
# {'仌', '老'}
# {'一套', '有人', '牛', '改车', '音响', '看到', '刚刚', '逼', '一百多万'}
# {'五万', '三万'}
# {'小弟', '俩', '格局', '低', '真的'}
# {'口语', '最后', '非得', '不好', '英语', '工地', '秀一秀'}
# {'总卖', '没', '保险', '丁', '钱'}
# {'卖', '保险'}
# {'看看', '十七', '看', '鼓掌'}
# {'北京', '欢乐谷', '看', '家门口'}
# {'哈哈哈', '笑', '死'}
# {'看', '去', '没开', '薛谦友', '互互'}
# {'想', '去'}
# {'纪宁', '逃离', '葫芦岛'}
# {'不吃', '笑', '死', '包子'}
# {'第一眼', '老八', '以为'}
# {'周瑜', '文化', '葫芦岛'}
# {'点', '地道', '重庆', '地方'}
# {'往事', '洋气'}
# {'碰杯', '不能'}
# {'漏底', '不是', '杯子'}
# {'请问', '牛排', '商家', '店', '想', '机器', '卖', '买', '联系'}
# {'吊'}
# {'地漏', '呆', '不赖'}
# {'带', '打卡', '重庆', '一起', '必须'}
# {'太低', '抠鼻', '质量'}
# {'龙哥', '福州', '是不是'}
# {'大哥', '水床', '舒不', '睡', '舒服', '问', '一下'}
# {'地方', '这种', '查封'}
# {'不到', '安逸', '认', '水床'}
# {'技师', '不行'}
# {'住', '包吃', '地方', '那种', '钱', '不要', '有个'}
# {'地址', '求'}
# {'地址', '求'}
# {'玩', '女人', '现在', '有钱'}
# {'呲牙', '捂脸'}
# {'真', '有钱', '抠鼻', '不好意思', '好', '说错'}
# {'请', '尊重', '互相'}
# {'这家', '哥', '福州', '店'}
# {'玫瑰', '赞赞赞', '鼓掌', '赞赞'}
# {'熟', '地方'}
# {'戴斯', '晋'}
# {'赞赞'}
# {'玩', '龙哥'}
# {'犀利', '龙哥', '你好'}
# {'呲牙'}
# {'不错', '看', '女'}
# {'呲牙', '玩腻'}
# {'韩国', '女明星', '长相', '所有', '碾压', '气质'}
# {'选择', '已经', '知道', '离婚', '正确'}
# {'怕', '座椅', '泣不成声', '弄脏', '赔不起'}
# {'私信', '纸', '已经', '泣不成声', '聪明', '男孩'}
# {'连表', '保时捷', '经典'}
# {'喔', '帕拉', '美丽', '红', '耀眼', '梅拉'}
# {'已经', '大金牙', '私信'}
# {'泣不成声', '同感'}
# {'帕纳', '女孩', '美拉', '没有'}
# {'保时', '泰看'}
# {'小帕', '点儿'}
# {'保时捷', '知道', '捂脸'}
# {'帕拉', '梅拉'}
# {'雇', '这车', '保姆'}
# {'私信', '看', '已经', '男性', '聪明'}
# {'帕拉', '车主', '标的', '露车', '不愿', '保时捷', '梅拉'}
# {'帕拉', '车主', '透露', '赞', '愿意', '梅拉'}
# {'一周', '保持', '不能'}
# {'帕拉', '女孩', '开奥拓', '不香', '梅拉'}
# {'众泰', '捂脸'}
# {'帕拉', '梅拉'}
# {'好', '内饰', '血腥'}
# {'炫', '别出心裁', '一把'}
# {'洁怕', '没', '保湿'}
# {'女孩', '没车'}
# {'口罩', '好', '喜欢', '方向盘'}
# {'帕拉', '梅拉'}
# {'帕拉', '梅拉'}
# {'同款', '红'}
# {'丢', '泣不成声', '手里', '砖头', '好', '远'}
# {'没', '怕'}
# {'真正', '买来', '洁癖', '车是', '不会', '坐人', '人'}
# {'没', '怕', '拉车', '标的', '泣不成声', '透露', '愿意', '主', '一位', '拉', '车'}
# {'五个', '炮筒', '知道', '帕美', '好'}
# {'帕拉', '剩下', '猜', '排除', '车标', '保时捷', '看不到', '可能', '好', '梅拉'}
# {'摸', '怕', '排除'}
# {'帕拉', '买', '梅拉'}
# {'不想', '突然', '好家伙', '努力'}
# {'拍标', '先烧', '灵机一动', '后拉缸', '机油', '拍车'}
# {'抖音', '豪车', '全是'}
# {'苦力', '做', '不去', '有钱', '可惜'}
# {'炫', '别出心裁', '一把'}
# {'洁怕', '没', '保湿'}
# {'女孩', '没车'}
# {'口罩', '好', '喜欢', '方向盘'}
# {'帕拉', '梅拉'}
# {'帕拉', '梅拉'}
# {'同款', '红'}
# {'丢', '泣不成声', '手里', '砖头', '好', '远'}
# {'没', '怕'}
# {'真正', '买来', '洁癖', '车是', '不会', '坐人', '人'}
# {'没', '怕', '拉车', '标的', '泣不成声', '透露', '愿意', '主', '一位', '拉', '车'}
# {'五个', '炮筒', '知道', '帕美', '好'}
# {'帕拉', '剩下', '猜', '排除', '车标', '保时捷', '看不到', '可能', '好', '梅拉'}
# {'摸', '怕', '排除'}
# {'帕拉', '买', '梅拉'}
# {'不想', '突然', '好家伙', '努力'}
# {'拍标', '先烧', '灵机一动', '后拉缸', '机油', '拍车'}
# {'抖音', '豪车', '全是'}
# {'苦力', '做', '不去', '有钱', '可惜'}
# {'类型', '捂脸', '不是', '喜欢', '四座'}
# {'帕拉', '真仙色', '梅拉'}
# {'帕拉', '房子', '发呆', '扒', '梅拉'}
# {'奔涌', '后浪'}
# {'干净', '泣不成声', '车'}
# {'富婆', '天', '泣不成声', '第三十四', '试图', '撼动'}
# {'摸', '怕'}
# {'帕拉', '泪奔', '梅拉', '无疑'}
# {'举报', '一下', '想想', '回来'}
# {'无疑', '保时捷'}
# {'抽烟', '算了', '不能'}
# {'捂脸', '没有', '干净', '装饰', '喜欢', '全车', '车'}
# {'懂事', '已经', '备孕', '戒酒', '男生', '戒烟'}
# {'想', '洁癖'}
# {'想', '买', '知道', '猪'}
# {'姐姐', '富婆'}
# {'一下', '装饰'}
# {'司机', '抠鼻', '招'}
# {'不想', '努力', '富婆'}
# {'摸', '呲牙', '怕'}
# {'感动', '第天', '富婆', '玫瑰'}
# {'帕拉', '梅拉'}
# {'没', '扒拉'}
# {'帕拉', '梅拉'}
# {'女人', '标的', '不愿', '透露', '众泰车'}
# {'好', '有车', '知道'}
# {'无语', '捂脸'}
# {'哈哈哈', '哈哈哈哈'}
# {'夫人', '有点', '搞笑'}
# {'演员', '胖胖', '老'}
# {'套', '捂脸', '模具'}
# {'做', '饼干', '模具'}
# {'强迫症', '福音'}
# {'捂脸', '冰', '模具', '专业', '工厂'}
# {'怎么回事', '看得', '贼', '舒服', '心里'}
# {'一看', '看', '没有', '老手', '手', '新手'}
# {'看', '鬼', '捂脸', '知道', '遍'}
# {'厂里', '朋友', '还要', '人'}
# {'科研项目', '好多', '每年', '个瓦伦堡', '基金', '资助'}
# {'是因为', '高中', '水平', '高深', '考试', '基本', '没有', '当时', '初', '算', '计算器', '好', '发展', '现在', '中学', '物理', '研究生', '数学', '不到', '化学'}
# {'合', '看', '天地', '当年', '山无棱', '夏雨荷'}
# {'估计', '被子', '回来'}
# {'已经', '傻', '搭理'}
# {'急', '欺负', '媳妇'}
# {'无助', '弱小', '可怜'}
# {'赶紧', '太', '严重', '高反', '真会', '下去', '死', '人'}
# {'快', '去', '看'}
# {'录', '捂脸'}
# {'姐妹花', '捂脸', '好一朵', '塑料'}
# {'佩奇', '红红火火', '到时候', '小猪'}
# {'点才', '捂脸', '说', '早上', '上班'}
# {'南北', '东西', '看', '不能', '时间差', '温度差'}
# {'哈哈哈', '哈哈哈哈'}
# {'冬天', '去'}
# {'奸笑', '省电', '晚上'}
# {'冬天', '赚'}
# {'漏油', '老师', '马', '捂脸'}
# {'区', '评论', '来看'}
# {'压力', '几天', '瘦'}
# {'厉害', '虚', '善', '比较', '面'}
# {'几秒', '二十万'}
# {'大金牙', '风扇', '不失', '武林'}
# {'次', '喝醉', '打倒', '秒', '不会'}
# {'打来', '找', '捂脸'}
# {'得瑟', '捂脸', '出来'}
# {'打来', '找'}
# {'无语', '逼真', '逗'}
# {'怕人', '下毒手', '水杯子'}
# {'不是', '马三倒'}
# {'故地重游', '感慨万千'}
# {'额', '拳来', '客气', '千万', '呦', '不要', '脸接', '发怒', '照样', '就算'}
# {'原型', '回', '一拳'}
# {'公安', '带走', '以为'}
# {'打拳', '人会'}
# {'网红', '现在'}
# {'六术', '还要', '显圣', '一起加油', '再次', '大师'}
# {'下次', '嘴', '记得'}
# {'徒弟', '马', '不要'}
# {'逼', '马牛'}
# {'上甘岭', '保国', '马'}
# {'蝶子', '扎猛子', '不知深浅'}
# {'捂脸', '伤好'}
# {'想', '笑', '捂脸', '看见'}
# {'喽', '三倒', '谦虚', '呲牙', '变得'}
# {'徒弟', '捂脸'}
# {'是不是', '钓鱼', '张抖音', '之前', '好像', '拍', '去', '老师', '呲牙'}
# {'高手', '水裆尿裤', '造', '德行'}
# {'我想静静', '灵机一动', '捂脸'}
# {'魑魅魍魉', '大行其道'}
# {'有所为', '老师', '马', '勇气可嘉'}
# {'公安', '带走', '以为'}
# {'打拳', '人会'}
# {'网红', '现在'}
# {'六术', '还要', '显圣', '一起加油', '再次', '大师'}
# {'下次', '嘴', '记得'}
# {'徒弟', '马', '不要'}
# {'逼', '马牛'}
# {'上甘岭', '保国', '马'}
# {'蝶子', '扎猛子', '不知深浅'}
# {'捂脸', '伤好'}
# {'想', '笑', '捂脸', '看见'}
# {'喽', '三倒', '谦虚', '呲牙', '变得'}
# {'徒弟', '捂脸'}
# {'是不是', '钓鱼', '张抖音', '之前', '好像', '拍', '去', '老师', '呲牙'}
# {'高手', '水裆尿裤', '造', '德行'}
# {'我想静静', '灵机一动', '捂脸'}
# {'魑魅魍魉', '大行其道'}
# {'有所为', '老师', '马', '勇气可嘉'}
# {'没什么', '输赢', '正常', '下来', '天下无敌', '生', '大不了'}
# {'彪哥', '气势', '没有'}
# {'打嘴'}
# {'凡尘', '打入'}
# {'嘴巴', '扇'}
# {'一会儿', '捂脸', '就让', '岀', '抬', '人'}
# {'捂脸', '揭开', '知道', '钻', '老鼠洞', '想', '他会', '现在', '不会', '全国', '骗术', '人民', '心里'}
# {'不耍', '打脸', '鞭'}
# {'戴', '口罩', '姓马', '呲牙', '好', '嗨'}
# {'呲牙'}
# {'风范', '大师', '捂脸'}
# {'害', '徒弟', '捂脸'}
# {'捂脸', '老马'}
# {'机会', '打到', '我来', '老师', '马'}
# {'方天画', '斩', '吕布', '义父', '人中', '专', '马中赤', '兔', '戟'}
# {'赞', '张光北'}
# {'来人取', '来看', '炮营'}
# {'方天画', '捅', '兔人', '吕布', '义夫', '专', '马中赤', '戟'}
# {'泣不成声', '拾玖'}
# {'大师', '马三倒', '师承'}
# {'休得', '放肆', '低调', '徒儿'}
# {'马拳', '正宗', '赞'}
# {'大师', '不是', '马', '捂脸'}
# {'派', '大马'}
# {'操作', '挺秀', '这波'}
# {'被骗', '网恋', '毛钱', '去年'}
# {'降龙十八掌', '一套', '打出'}
# {'干', '完'}
# {'看清楚', '一下', '鞭'}
# {'公园', '派', '捂脸'}
# {'师兄弟', '保国', '马'}
# {'呲牙', '太级', '门', '混元'}
# {'派', '马三倒', '捂脸'}
# {'始祖', '步', '欧洲'}
# {'看来', '派', '捂脸', '峨眉'}
# {'一看', '知道', '马派'}
# {'派', '乱舞'}
# {'泰森', '师从'}
# {'篮', '三步', '以为'}
# {'保国', '师兄', '马'}
# {'蒙圈', '耳光'}
# {'大师', '出场', '马'}
# {'保国', '徒弟', '马'}
# {'奸笑', '师兄', '派', '沙雕'}
# {'捂脸'}
# {'表示', '老师', '马', '不服'}
# {'天赋', '传武', '表演', '大师', '之上', '人'}
# {'一看', '捂脸', '保国', '毕业', '马', '手下'}
# {'捂脸', '马派', '太极'}
# {'保国', '徒弟', '认识', '马', '二'}
# {'强赞', '几招', '大师', '比马', '耍'}
# {'打赢', '没', '问题', '捂脸', '大师', '马'}
# {'看来', '派', '捂脸', '峨眉'}
# {'一看', '知道', '马派'}
# {'派', '乱舞'}
# {'泰森', '师从'}
# {'篮', '三步', '以为'}
# {'保国', '师兄', '马'}
# {'蒙圈', '耳光'}
# {'大师', '出场', '马'}
# {'保国', '徒弟', '马'}
# {'奸笑', '师兄', '派', '沙雕'}
# {'捂脸'}
# {'表示', '老师', '马', '不服'}
# {'天赋', '传武', '表演', '大师', '之上', '人'}
# {'一看', '捂脸', '保国', '毕业', '马', '手下'}
# {'捂脸', '马派', '太极'}
# {'保国', '徒弟', '认识', '马', '二'}
# {'强赞', '几招', '大师', '比马', '耍'}
# {'打赢', '没', '问题', '捂脸', '大师', '马'}
# {'形意', '太极', '门', '混元'}
# {'看多', '武侠片'}
# {'真见', '打架'}
# {'徒弟', '马派', '捂脸'}
# {'派', '一看', '花果山'}
# {'保国', '马', '弟子'}
# {'摩擦', '魔鬼', '步伐', '大师', '堪比马'}
# {'大师', '马'}
# {'猴拳', '硬派'}
# {'捂脸', '宋', '小宝'}
# {'师傅', '马'}
# {'肯定', '徒弟', '马三倒', '捂脸'}
# {'传人', '门派', '马', '捂脸'}
# {'造型', '看'}
# {'笑', '死', '捂脸'}
# {'这种', '真', '保国', '马', '好', '处理', '交给', '角色'}
# {'马派', '疯派', '抽'}
# {'徒弟', '师傅', '马'}
# {'民间', '派', '武当', '舞姿'}
# {'关门', '赞', '弟子', '老师', '马'}
# {'好', '逼', '牛'}
# {'保国', '徒弟', '马', '赞'}
# {'大巴', '捂脸'}
# {'自娱自乐', '捂脸'}
# {'悠着点', '容易', '一不小心'}
# {'马哥', '徒弟', '二'}
# {'没', '刚才', '老头', '简简单单', '五鞭', '看见'}
# {'广汉', '以后', '年', '通', '好久'}
# {'小可爱', '抠鼻', '艾特'}
# {'建设路', '地铁', '不得', '咋个'}
# {'三十', '八号', '线', '呲牙', '号线'}
# {'没', '脸', '微笑', '笑', '烂', '新'}
# {'强赞', '承认', '不得不', '曼联', '真的'}
# {'最近', '微笑', '抖音', '泣不成声', '知道', '总听'}
# {'更松', '头发', '松', '阿利'}
# {'石化', '肚腩', '看到'}
# {'礼品', '好多', '送', '年', '玩'}
# {'萨拉', '范戴克', '笑', '松', '赫对', '阿里'}
# {'利物浦', '精神', '一种'}
# {'老歌', '路过', '好听'}
# {'尼格', '好像', '不多昂', '利物浦'}
# {'呲牙', '长肉'}
# {'最后', '南野', '拓实', '看太像', '卧槽', '李毅'}
# {'冠军', '利物浦'}
# {'竞玩', '马', '捂脸'}
# {'捧杯', '看', '捂脸', '今年', '我要'}
# {'捂脸', '利物浦', '抖音', '天', '色'}
# {'冠军', '利物浦', '赞赞'}
# {'爱', '愛了', '巧克力'}
# {'秒', '灵机一动'}
# {'英超', '快点', '看', '利物浦', '捧起', '奖杯', '开赛'}
# {'冠军', '利物浦'}
# {'礼品', '好多', '送', '年', '玩'}
# {'看', '守门', '第三个', '应该', '不会'}
# {'看', '安菲尔德', '想', '管理员', '去', '一天', '饮水机'}
# {'玩', '朋友', '推荐'}
# {'倍', '昨天', '拿下', '看', '比赛', '一举', '下', '翻', '捂脸', '随机', '激动', '一把', '没想到', '呲牙', '拜仁'}
# {'呦', '不错'}
# {'一台', '玩到', '朋友', '两栋', '房', '平台', '跑车', '小'}
# {'小肚子', '叔', '捂脸', '看渣'}
# {'一圈', '圆', '捂脸', '渣叔'}
# {'雷神'}
# {'全员', '看看', '头发'}
# {'捂脸', '胖', '渣叔', '阿利', '姑娘', '松成'}
# {'利物浦', '亲亲', '足球', '求翻', '俱乐部'}
# {'好久没', '见', '冠军'}
# {'冠军', '利物浦', '赞赞'}
# {'爱', '愛了', '巧克力'}
# {'秒', '灵机一动'}
# {'英超', '快点', '看', '利物浦', '捧起', '奖杯', '开赛'}
# {'冠军', '利物浦'}
# {'礼品', '好多', '送', '年', '玩'}
# {'看', '守门', '第三个', '应该', '不会'}
# {'看', '安菲尔德', '想', '管理员', '去', '一天', '饮水机'}
# {'玩', '朋友', '推荐'}
# {'倍', '昨天', '拿下', '看', '比赛', '一举', '下', '翻', '捂脸', '随机', '激动', '一把', '没想到', '呲牙', '拜仁'}
# {'呦', '不错'}
# {'一台', '玩到', '朋友', '两栋', '房', '平台', '跑车', '小'}
# {'小肚子', '叔', '捂脸', '看渣'}
# {'一圈', '圆', '捂脸', '渣叔'}
# {'雷神'}
# {'全员', '看看', '头发'}
# {'捂脸', '胖', '渣叔', '阿利', '姑娘', '松成'}
# {'利物浦', '亲亲', '足球', '求翻', '俱乐部'}
# {'好久没', '见', '冠军'}
# {'耶', '捂脸', '鼓掌', '一起加油', '冠军', '赞', '奖杯', '招手', '呲牙'}
# {'打着', '赞', '大夏', '喜欢', '年', '广告牌', '高楼'}
# {'酸酸的', '心里', '看到', '流泪'}
# {'庄园', '清盘', '终于', '多年', '紫金', '呲牙'}
# {'北京', '不是', '热爱', '这真'}
# {'用时', '有人', '当年', '笑哭', '楼', '好像', '跳下来', '秒', '最高', '京广中心', '北京'}
# {'商业区', '丽泽', '平分秋色', '想', '现在', '建'}
# {'没', '捂脸', '变', '京广中心', '一下'}
# {'当年', '阿森纳', '赞助商', '胸前'}
# {'塌', '微笑', '楼楼'}
# {'后', '样子', '再', '过年'}
# {'亮', '马桥', '长城', '大厦', '捂脸', '桥', '看到', '往前', '农展'}
# {'够', '年车', '捂脸'}
# {'京广桥', '桥', '北向南', '农展'}
# {'原住民', '哈哈哈', '桥', '片儿', '农展'}
# {'兆龙', '呲牙'}
# {'赶紧', '走', '麻烦'}
# {'阴阳怪气', '文案'}
# {'桥', '农展'}
# {'憨笑', '农展馆', '门口'}
# {'广告', '没'}
# {'一定', '全部', '城市', '怀旧', '程度', '老', '以前', '玩', '发达', '绝望的凝视', '欧洲', '建筑'}
# {'合适', '怕', '文案'}
# {'乐队', '黑豹'}
# {'广告', '没'}
# {'一定', '全部', '城市', '怀旧', '程度', '老', '以前', '玩', '发达', '绝望的凝视', '欧洲', '建筑'}
# {'合适', '怕', '文案'}
# {'乐队', '黑豹'}
# {'保存', '微笑', '回去', '手机', '现在', '骚扰电话', '想要', '上海', '不要', '有个'}
# {'一定', '有钱', '炸掉'}
# {'归属', '中国移动', '升级', '套餐', '换', '每天', '差不多', '广州', '深圳', '白眼', '不是', '三个', '打电话', '号码', '东莞'}
# {'没', '问题', '看', '有人', '地方', '经常', '不姓', '房', '邱晕', '离开', '买', '上次', '去', '几年', '问', '看过'}
# {'诈骗', '集团'}
# {'号', '地方', '区', '大多', '三位数'}
# {'第次', '记得', '接到', '他成', '失恋', '骚扰电话', '第任', '后来', '男友', '小时', '俩个', '聊', '陪'}
# {'上海', '不在'}
# {'明白', '说', '原因', '点', '迷糊'}
# {'不是', '录'}
# {'超强', '赞赞赞', '表达能力'}
# {'泣不成声', '清风明月', '挽'}
# {'小', '两只手', '泪奔', '格局'}
# {'闭上眼睛', '仔细听'}
# {'不至于'}
# {'机会', '故事', '告诉', '不等', '人'}
# {'倒闭', '吃', '菜馆', '那家', '爱', '附近', '学校', '东北', '泪奔'}
# {'人', '好', '可爱', '东北'}
# {'真香', '锅包肉', '一大', '盘子'}
# {'吃不饱', '说', '不能', '难吃', '说饭'}
# {'店', '现在', '少'}
# {'吃', '大份', '米线', '三个', '一碗', '够', '人'}
# {'老板娘', '使劲', '质量', '第一颗', '黑洞', '出现', '人造', '去', '上次', '辽宁', '一碗', '里', '压', '世界', '往碗', '米饭'}
# {'说', '想', '其实', '东北', '存在', '看看', '人'}
# {'老板', '觉得', '没有', '不了', '自助餐厅', '教育', '不信'}
